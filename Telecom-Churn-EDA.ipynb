# %% [markdown]
# ###### Telecom Churn Rate

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Exploratory-Analysis/data/telecom_churn.csv')

# %%
rows,cols = df.shape
print("Total number of rows",rows)
print("Total number of cols",cols)
# Out:
# Total number of rows 3333
# Total number of cols 20

# %%
print("Printing all column names of the dataframe")
print(df.columns)
# Out:
# Printing all column names of the dataframe
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
# State                     3333 non-null object
# Account length            3333 non-null int64
# Area code                 3333 non-null int64
# International plan        3333 non-null object
# Voice mail plan           3333 non-null object
# Number vmail messages     3333 non-null int64
# Total day minutes         3333 non-null float64
# Total day calls           3333 non-null int64
# Total day charge          3333 non-null float64
# Total eve minutes         3333 non-null float64
# Total eve calls           3333 non-null int64
# Total eve charge          3333 non-null float64
# Total night minutes       3333 non-null float64
# Total night calls         3333 non-null int64
# Total night charge        3333 non-null float64
# Total intl minutes        3333 non-null float64
# Total intl calls          3333 non-null int64
# Total intl charge         3333 non-null float64
# ...

# %%
df['Churn'] = df['Churn'].astype('int64')
df['Churn'].value_counts()
# Out:
# 0    2850
# 1     483
# Name: Churn, dtype: int64

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df.describe(include = ['object','bool'])
# Out:
#        State International plan Voice mail plan
# count   3333               3333            3333
# unique    51                  2               2
# top       WV                 No              No
# freq     106               3010            2411

# %%
df['Churn'].value_counts()
# Out:
# 0    2850
# 1     483
# Name: Churn, dtype: int64

# %%
df['Churn'].value_counts(normalize='True')
# Out:
# 0    0.855086
# 1    0.144914
# Name: Churn, dtype: float64

# %%
##Sort Values, inplace to return a new dataframe, axis=0 (by default means cols), by column to be given for column Name, and ascending is soritng orde)
df.sort_values(by = 'Total day charge', inplace = False, axis = 0, ascending =False).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 365     CO             154        415                 No              No
# 985     NY              64        415                Yes              No
# 2594    OH             115        510                Yes              No
# 156     OH              83        415                 No              No
# 605     MO             112        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 365                       0              350.8               75
# 985                       0              346.8               55
# 2594                      0              345.3               81
# 156                       0              337.4              120
# 605                       0              335.5               77
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
## Multiple Sorting. Order of Precedence given.
df.sort_values(by=['Total day charge','Total eve charge'],ascending = [False,True]).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 365     CO             154        415                 No              No
# 985     NY              64        415                Yes              No
# 2594    OH             115        510                Yes              No
# 156     OH              83        415                 No              No
# 605     MO             112        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 365                       0              350.8               75
# 985                       0              346.8               55
# 2594                      0              345.3               81
# 156                       0              337.4              120
# 605                       0              335.5               77
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df['Churn'].mean()
# Out:
# 0.14491449144914492

# %%
df[df['Churn'] == 1].mean()
# Out:
# Account length            102.664596
# Area code                 437.817805
# Number vmail messages       5.115942
# Total day minutes         206.914079
# Total day calls           101.335404
# Total day charge           35.175921
# Total eve minutes         212.410145
# Total eve calls           100.561077
# Total eve charge           18.054969
# Total night minutes       205.231677
# Total night calls         100.399586
# Total night charge          9.235528
# Total intl minutes         10.700000
# Total intl calls            4.163561
# Total intl charge           2.889545
# Customer service calls      2.229814
# Churn                       1.000000
# dtype: float64

# %%
df[df['Churn'] == 1]['Total day minutes'].mean()
# Out:
# 206.91407867494814

# %%
df[(df['Churn'] == 0) & (df['International plan'] == 'No')]['Total intl calls'].max()
# Out:
# 19

# %%
#rows are index, cols is columns, iloc given when integer given
df.iloc[0:5,0:3]
# Out:
#   State  Account length  Area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415

# %%
#rows are index, cols is columns, loc given when column names are given
df.loc[0:5,['State', 'Total day minutes']]
# Out:
#   State  Total day minutes
# 0    KS              265.1
# 1    OH              161.6
# 2    NJ              243.4
# 3    OH              299.4
# 4    OK              166.7
# 5    AL              223.4

# %%
#apply function - to apply a operation to all columns
df.apply(np.max)
# Out:
# State                        WY
# Account length              243
# Area code                   510
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        51
# Total day minutes         350.8
# Total day calls             165
# Total day charge          59.64
# Total eve minutes         363.7
# Total eve calls             170
# Total eve charge          30.91
# Total night minutes         395
# Total night calls           175
# Total night charge        17.77
# Total intl minutes           20
# Total intl calls             20
# Total intl charge           5.4
# Customer service calls        9
# Churn                         1
# dtype: object

# %%
len(df.State.unique())
# Out:
# 51

# %%
## lambda arg : expression
## Here arg state = df.State
## expression run is to compare each state initial first letter to check if it is W
## head gives first 5 data points
df[df.State.apply(lambda state: state[0] == 'W')]['State'].head()
# Out:
# 9     WV
# 26    WY
# 44    WI
# 49    WY
# 54    WY
# Name: State, dtype: object

# %%
## Alternatively
df[df['State'].apply(lambda state: state[0] == 'W')]['State'].head()
# Out:
# 9     WV
# 26    WY
# 44    WI
# 49    WY
# 54    WY
# Name: State, dtype: object
